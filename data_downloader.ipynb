# %%
# !python3 ./imagenetDownloader.py n02437312 ../dd2424_project/dataset --humanreadable -F --images=120 --minsize=7000 -j10
# Out:
# response: n02437312
#
# 2
# ['n02437312']
# response: http://www.julierosser.com/Cross-Country%20Adventure/1fae1f10.jpg
# http://macro.dokkyomed.ac.jp/mammal/images/living/small/21-16s.jpg
# http://farm1.static.flickr.com/100/309175306_cc6db0020e.jpg
# http://farm1.static.flickr.com/125/370983391_61b9a84258.jpg
# http://members.aol.com/zoonet/pictures/dromedary.jpg
# http://static.flickr.com/40/79813775_dca5c11568.jpg
# http://farm1.static.flickr.com/33/42567382_6a8fdd950c.jpg
# http://farm3.static.flickr.com/2417/2199597687_a28b1397be.jpg
# http://www.petsencyclopedia.com/critter_images/mammals/other_exotics/OEX_0004766_20011004192421.jpg
# http://images.encarta.msn.com/xrefmedia/sharemed/targets/video/T220298A.jsm
# http://fotos.naturspot.de/fotos/11-253.jpg
# http://fohn.net/camel-pictures-facts/the-pictures/Dromedary-Hand.jpg
# http://farm2.static.flickr.com/1160/612479269_5b78b4e451.jpg
# http://www.isrvma.org/images/58_2_cover.jpg
# ...

# %%
with open('imagenetDownloader.py', 'rb+') as f:
    content = f.read()
    f.seek(0)
    f.write(content.replace(b'\r', b''))
    f.truncate()

# %%
# !python --version
# Out:
# Python 2.7.13
